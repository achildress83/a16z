# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import requests
import json

# %%
# from defipulse.com
api_key = 'private key'

# %% [markdown]
# ### Total Value Locked (TVL) in DeFi Lending Category

# %%
parameters = {'api-key': api_key, 'category': 'lending'}
url = 'https://data-api.defipulse.com/api/v1/defipulse/api/GetHistory?'

# %%
r1 = requests.get(url,params=parameters)

# %%
r1.status_code == requests.codes.ok
# Out:
# True

# %%
resp = r1.json()

# %%
tvl_all = pd.DataFrame.from_dict(resp)
tvl_all.head()
# Out:
#     timestamp        tvlUSD        tvlETH            BTC           ETH  \
# 0  1602565200  1.101602e+10  2.930005e+07  146826.914950  8.384441e+06
# 1  1602547200  1.108794e+10  2.923715e+07  146719.351061  8.380397e+06
# 2  1602460800  1.091963e+10  2.964042e+07  144087.832614  8.483471e+06
# 3  1602374400  1.073252e+10  2.941901e+07  142642.913861  8.338526e+06
# 4  1602288000  1.065112e+10  2.959170e+07  141683.019587  8.228843e+06
#
#             DAI
# 0  8.636783e+08
# 1  8.636718e+08
# 2  8.592992e+08
# 3  8.474533e+08
# 4  8.486329e+08

# %%
tvl_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1170 entries, 0 to 1169
# Data columns (total 6 columns):
# timestamp    1170 non-null object
# tvlUSD       1170 non-null float64
# tvlETH       1170 non-null float64
# BTC          1170 non-null float64
# ETH          1170 non-null float64
# DAI          1170 non-null float64
# dtypes: float64(5), object(1)
# memory usage: 55.0+ KB

# %%
# converting unix epoch to timestamp
tvl_all['timestamp'] = pd.to_datetime(tvl_all['timestamp'],unit='s')

# %%
# converting timestamp to date
tvl_all['timestamp'] = tvl_all['timestamp'].dt.date

# %%
#there may be more than one timestamp associated with a date. Dropping duplicates
tvl_all.drop_duplicates(subset='timestamp',keep='first',inplace=True)

# %% [markdown]
# ### TVL in Compound

# %%
comp_parameters = {'api-key': api_key, 'project': 'compound'}
url = 'https://data-api.defipulse.com/api/v1/defipulse/api/GetHistory?'

# %%
r2 = requests.get(url,params=comp_parameters)

# %%
r2.status_code == requests.codes.ok
# Out:
# True

# %%
resp2 = r2.json()

# %%
tvl_comp = pd.DataFrame.from_dict(resp2)
tvl_comp.head()
# Out:
#     timestamp     tvlUSD        tvlETH          BTC            ETH  \
# 0  1602565200  844013679  2.214155e+06  4430.741082  818488.345263
# 1  1602547200  846216521  2.200766e+06  4419.491380  819332.258795
# 2  1602460800  831133853  2.224960e+06  4187.815062  816567.553204
# 3  1602374400  825401893  2.230454e+06  3407.161035  802717.923704
# 4  1602288000  818467324  2.242253e+06  2838.944538  787701.967270
#
#             DAI
# 0  2.790619e+08
# 1  2.786128e+08
# 2  2.775619e+08
# 3  2.710508e+08
# 4  2.715240e+08

# %%
tvl_comp['timestamp'] = pd.to_datetime(tvl_comp['timestamp'],unit='s')

# %%
tvl_comp['timestamp'] = tvl_comp['timestamp'].dt.date

# %%
tvl_comp.drop_duplicates(subset='timestamp',keep='first',inplace=True)

# %% [markdown]
# ### TVL in Aave

# %%
lend_parameters = {'api-key': api_key, 'project': 'aave'}
url = 'https://data-api.defipulse.com/api/v1/defipulse/api/GetHistory?'

# %%
r3 = requests.get(url,params=lend_parameters)

# %%
r3.status_code == requests.codes.ok
# Out:
# True

# %%
resp3 = r3.json()

# %%
tvl_lend = pd.DataFrame.from_dict(resp3)
tvl_lend.head()
# Out:
#     timestamp      tvlUSD        tvlETH           BTC            ETH  \
# 0  1602565200  1155327363  3.030844e+06  14624.195471  324194.155522
# 1  1602547200  1153925270  3.001028e+06  14222.619372  325362.952135
# 2  1602460800  1132386846  3.031420e+06  15436.955809  304956.790832
# 3  1602374400  1137047574  3.072603e+06  16269.252777  286170.829958
# 4  1602288000  1181711359  3.237388e+06  16348.918887  281651.608863
#
#             DAI
# 0  9.101043e+06
# 1  9.183987e+06
# 2  7.263111e+06
# 3  1.020432e+07
# 4  9.083364e+06

# %%
tvl_lend['timestamp'] = pd.to_datetime(tvl_lend['timestamp'],unit='s')

# %%
tvl_lend['timestamp'] = tvl_lend['timestamp'].dt.date

# %%
tvl_lend.drop_duplicates(subset='timestamp',keep='first',inplace=True)

# %% [markdown]
# ### Joining TVL dataframes

# %%
tvl_all_comp = pd.merge(tvl_all, tvl_comp,how='left',on='timestamp',suffixes=('_all','_comp'))

# %%
df_tvl = pd.merge(tvl_all_comp, tvl_lend,how='left',on='timestamp')

# %%
df_tvl.head()
# Out:
#     timestamp    tvlUSD_all    tvlETH_all        BTC_all       ETH_all  \
# 0  2020-10-13  1.101602e+10  2.930005e+07  146826.914950  8.384441e+06
# 1  2020-10-12  1.091963e+10  2.964042e+07  144087.832614  8.483471e+06
# 2  2020-10-11  1.073252e+10  2.941901e+07  142642.913861  8.338526e+06
# 3  2020-10-10  1.065112e+10  2.959170e+07  141683.019587  8.228843e+06
# 4  2020-10-09  1.048760e+10  3.029239e+07  140647.909789  8.268605e+06
#
#         DAI_all  tvlUSD_comp   tvlETH_comp     BTC_comp       ETH_comp  \
# 0  8.636783e+08  844013679.0  2.214155e+06  4430.741082  818488.345263
# 1  8.592992e+08  831133853.0  2.224960e+06  4187.815062  816567.553204
# 2  8.474533e+08  825401893.0  2.230454e+06  3407.161035  802717.923704
# 3  8.486329e+08  818467324.0  2.242253e+06  2838.944538  787701.967270
# 4  8.435103e+08  826030824.0  2.352493e+06  2613.845646  793002.717674
#
#        DAI_comp        tvlUSD        tvlETH           BTC            ETH  \
# 0  2.790619e+08  1.155327e+09  3.030844e+06  14624.195471  324194.155522
# 1  2.775619e+08  1.132387e+09  3.031420e+06  15436.955809  304956.790832
# 2  2.710508e+08  1.137048e+09  3.072603e+06  16269.252777  286170.829958
# 3  2.715240e+08  1.181711e+09  3.237388e+06  16348.918887  281651.608863
# 4  2.701746e+08  1.184257e+09  3.372703e+06  17040.686564  288755.452865
#
#             DAI
# 0  9.101043e+06
# 1  7.263111e+06
# 2  1.020432e+07
# 3  9.083364e+06
# 4  1.189098e+07

# %%
#df_tvl.to_csv('tvl_data.csv')
